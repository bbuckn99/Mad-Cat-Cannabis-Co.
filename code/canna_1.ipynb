# %% [markdown]
# # Clean Cannabis

# %% [markdown]
# This notebook is the cleaning of the dataset from:
# - https://www.dolthub.com/repositories/dolthub/marijuana-data/query/master?q=SELECT+*+FROM+%60leafly%60+ORDER+BY+%60strain%60+ASC%2C+%60effects%60+ASC+LIMIT+1000

# %%
import pandas as pd

# %%
file_path = r'C:\Users\Baile\Documents\DSI 24\capstone\marijuana-data.csv.csv'
weed = pd.read_csv(file_path)

# %%
weed.head()
# Out:
#        strain    type  rating                                     effects  \
# 0      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     0.0                                         NaN
#
#                       flavor  \
# 0        Earthy,Sweet,Citrus
# 1    Spicy/Herbal,Sage,Woody
# 2  Apricot,Citrus,Grapefruit
# 3       Citrus,Earthy,Orange
# 4                        NaN
#
#                                          description
# 0  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  1024 is a sativa-dominant hybrid bred in Spain...
# 2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 3  Also known as Kosher Tangie, 24k Gold is a 60%...
# 4  3 Bears OG by Mephisto Genetics is an autoflow...

# %%
weed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   strain       1000 non-null   object
#  1   type         1000 non-null   object
#  2   rating       1000 non-null   float64
#  3   effects      964 non-null    object
#  4   flavor       937 non-null    object
#  5   description  989 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
weed.dtypes
# Out:
# strain          object
# type            object
# rating         float64
# effects         object
# flavor          object
# description     object
# dtype: object

# %%
weed.columns
# Out:
# Index(['strain', 'type', 'rating', 'effects', 'flavor', 'description'], dtype='object')

# %%
weed.shape
# Out:
# (1000, 6)

# %% [markdown]
# # Filling Null Values

# %%
weed.isnull().sum()
# Out:
# strain          0
# type            0
# rating          0
# effects        36
# flavor         63
# description    11
# dtype: int64

# %% [markdown]
# ## Effects Column

# %%
null_effects = weed[weed['effects'].isnull()]

# %%
null_effects
# Out:
#                           strain    type  rating effects  \
# 4                     3-Bears-Og  indica     0.0     NaN
# 15                        831-Og  indica     5.0     NaN
# 52                     Afrikaner  sativa     0.0     NaN
# 93                     Alpha-Cow  sativa     5.0     NaN
# 106           Amnesia-Ganja-Haze  sativa     5.0     NaN
# 153                 Bad-Azz-Kush  hybrid     5.0     NaN
# 185                 Bermuda-Sour  hybrid     0.0     NaN
# 259                Blizzard-Bush  hybrid     0.0     NaN
# 319                   Blue-Trane  hybrid     0.0     NaN
# 349          Blueberry-Triple-Og  indica     4.0     NaN
# 358             Bodega-Bubblegum  hybrid     0.0     NaN
# 363                     Boombaye  hybrid     0.0     NaN
# 377               Bright-Moments  hybrid     0.0     NaN
# 385                   Bubba-Doja  indica     4.0     NaN
# 387                   Bubba-Hash  indica     0.0     NaN
# 409                Burnt-Cookies  hybrid     0.0     NaN
# 413                           C3  hybrid     5.0     NaN
# 417                  Cackleberry  hybrid     0.0     NaN
# 428                     Calyx-Og  hybrid     0.0     NaN
# 445  Caramel-Kona-Coffee-Cookies  hybrid     0.0     NaN
# 466            Cbd-Rich-Blessing  sativa     0.0     NaN
# 504                  Cherry-Fire  hybrid     0.0     NaN
# 523                   Chocoholic  hybrid     0.0     NaN
# 530           Chocolate-Meringue  indica     0.0     NaN
# 536              Chocolate-Tonic  hybrid     0.0     NaN
# 613                      Cronuts  hybrid     4.7     NaN
# 664            Dirty-Old-Bastard  indica     5.0     NaN
# 697                   Dr-Bubbles  hybrid     4.0     NaN
# 701                   Dr-Quantum  hybrid     0.0     NaN
# 768                      Erdpurt  indica     0.0     NaN
# 788              Fighting-Buddha  sativa     5.0     NaN
# 818                 Frosty-Jesus  hybrid     5.0     NaN
# 832                      G-Force  indica     5.0     NaN
# 877               Godzilla-Blood  hybrid     0.0     NaN
# 891                  Golden-Soda  hybrid     0.0     NaN
# 917                   Grape-Dawg  hybrid     0.0     NaN
#
#                    flavor                                        description
# 4                     NaN  3 Bears OG by Mephisto Genetics is an autoflow...
# 15                    NaN  831 OG, aka Santa Cruz OG, is an indica-domina...
# 52                    NaN  Afrikaner by Cannabaal and master grower Waldo...
# 93                    NaN  Alpha Cow is a sativa strain that brings toget...
# 106                   NaN  Amnesia Ganja Haze is another award-winning st...
# 153                   NaN  Bad Azz Kush by Barney’s Farm was created with...
# 185                   NaN  Bermuda Sour by Deschutes Growery is a hybrid ...
# 259                   NaN  Blizzard Bush by Greenpoint Seeds is a resinou...
# 319                   NaN  Blue Trane is a cut with a mysterious heritage...
# 349                   NaN  Blueberry Triple OG, also known as Triple Blue...
# 358                   NaN  Bodega Bubblegum by Greenpoint Seeds combines ...
# 363                   NaN  Boombaye by Mr. Mack’s Snack is a CBD-rich str...
# 377                   NaN  Bright Moments by Gage Green Group is a delici...
# 385                   NaN  Bubba Doja by Quest Genetics is a heavy indica...
# 387                   NaN  Bubba Hash by Ace Seeds is a stout indica-domi...
# 409                   NaN  Burnt Cookies is another flavorful Cookies cro...
# 413                   NaN  C3 is an indica-dominant cross between Chemdaw...
# 417                   NaN  Crackleberry by Greenpoint Seeds is a fuel-dri...
# 428                   NaN  Calyx OG (also known as Calyx OG #3) is a bala...
# 445                   NaN  Caramel Kona Coffee Cookies by Pua Mana 1st Ha...
# 466                   NaN  CBD Rich Blessing by Bodhi Seeds is a 2:1 THC/...
# 504                   NaN  Cherry Fire is a potent mixture of Cherry Pie ...
# 523                   NaN  Chocoholic by Mighty Irish Seeds is a flavorfu...
# 530                   NaN  Chocolate Meringue is another sweet offering b...
# 536                   NaN  Chocolate Tonic by Purple Caper Seeds is a 1:1...
# 613                   NaN  Cronuts is another twist on the West Coast won...
# 664  Spicy/Herbal,Flowery  Dirty Old Bastard (also known as Dirty, Ol’ Di...
# 697                   NaN  Dr. Bubbles is a delicious strain with roots i...
# 701                   NaN  Dr. Quantum is an indica-dominant cross of Dr....
# 768                   NaN  ErdPurt is another indica-dominant strain from...
# 788                   NaN  Fighting Buddha by Chimera Seeds is a energeti...
# 818                   NaN  Frosty Jesus is a clone-only strain from Rebel...
# 832                   NaN  G-Force by Flying Dutchman is a hearty G13 and...
# 877                   NaN  Godzilla Blood by Pua Mana 1st Hawaiian Pakalo...
# 891                   NaN  Golden Soda by Calyx Garden is a hybrid strain...
# 917                   NaN  Grape Dawg is an indica-leaning hybrid created...

# %%
effects_dict = {
    '3-Bears-Og': 'Relaxed, Euphoric',
    '831-Og': 'Relaxed, Hungry, Creative',
    'Afrikaner': 'Euphoric, Sleepy',
    'Alpha-Cow': 'Relaxed',
    'Amnesia-Ganja-Haze': 'Relaxed',
    'Bad-Azz-Kush': 'Relaxed, Uplifted',
    'Bermuda-Sour': 'Relaxed, Uplifted, Hungry',
    'Blizzard-Bush': 'Relaxed, Happy, Uplifted',
    'Blue-Trane': 'Relaxed, Sleepy',
    'Blueberry-Triple-Og': 'Relaxed, Happy, Uplifted, Tingly',
    'Bodega-Bubblegum': 'Uplifted, Energized',
    'Boombaye': 'Sleepy, Euphoric',
    'Bright-Moments': 'Social, Euphoric',
    'Bubba-Doja': 'Relaxed, Sleepy, Euphoric',
    'Bubba-Hash': 'Relaxed, Hungry',
    'Burnt-Cookies': 'Social, Uplifted, Happy, Tingly',
    'C3': 'Relaxed, Sleepy, Uplifted, Euphoric',
    'Cackleberry': 'Euphoric, Relaxed, Social',
    'Calyx-Og': 'Creative, Hungry, Uplifted, Relaxed',
    'Caramel-Kona-Coffee-Cookies': 'Talkative, Creative, Energetic, Uplifted',
    'Cbd-Rich-Blessing': 'Relaxed, Happy, Uplifted',
    'Cherry-Fire': 'Calm, Uplifted, Hungry, Creative',
    'Chocoholic': 'Relaxed, Hungry, Sleepy',
    'Chocolate-Meringue': 'Social, Hungry, Euphoric',
    'Chocolate-Tonic': 'Relaxed, Happy, Creative, Uplifted',
    'Cronuts': 'Uplifted, Energized, Euphoric',
    'Dirty-Old-Bastard': 'Relaxed, Happy, Social',
    'Dr-Bubbles': 'Focused, Social, Euphoric',
    'Dr-Quantum': 'Uplifted, Happy, Creative',
    'Erdpurt': 'Relaxed, Happy, Creative',
    'Fighting-Buddha': 'Creative, Social, Uplifted, Focused',
    'Frosty-Jesus': 'Relaxed, Hungry, Tingly',
    'G-Force': 'Sleepy, Relaxed',
    'Godzilla-Blood': 'Uplifted, Happy, Euphoric',
    'Golden-Soda': 'Relaxed, Happy, Uplifted',
    'Grape-Dawg': 'Relaxed, Happy, Sleepy, Hungry'
}

# %%
for strain, effects in effects_dict.items():
    weed.loc[weed['strain'] == strain, 'effects'] = effects

# %%
weed.head()
# Out:
#        strain    type  rating                                     effects  \
# 0      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     0.0                           Relaxed, Euphoric
#
#                       flavor  \
# 0        Earthy,Sweet,Citrus
# 1    Spicy/Herbal,Sage,Woody
# 2  Apricot,Citrus,Grapefruit
# 3       Citrus,Earthy,Orange
# 4                        NaN
#
#                                          description
# 0  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  1024 is a sativa-dominant hybrid bred in Spain...
# 2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 3  Also known as Kosher Tangie, 24k Gold is a 60%...
# 4  3 Bears OG by Mephisto Genetics is an autoflow...

# %%
weed.isnull().sum()
# Out:
# strain          0
# type            0
# rating          0
# effects         0
# flavor         63
# description    11
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Flavors Column

# %%
null_flavors = weed[weed['flavor'].isnull()]

# %%
null_flavors[['strain', 'flavor']]
# Out:
#                           strain flavor
# 4                     3-Bears-Og    NaN
# 15                        831-Og    NaN
# 30                    Acid-Dough    NaN
# 52                     Afrikaner    NaN
# 85              Allen-Iverson-Og    NaN
# 93                     Alpha-Cow    NaN
# 98                     Als-Dream    NaN
# 103                     Amethyst    NaN
# 106           Amnesia-Ganja-Haze    NaN
# 123                 Arabian-Gold    NaN
# 153                 Bad-Azz-Kush    NaN
# 167                      Batgirl    NaN
# 175                   Bcn-Diesel    NaN
# 185                 Bermuda-Sour    NaN
# 192           Berts-Cookie-Dough    NaN
# 213                    Birds-Eye    NaN
# 231             Black-Larry-Bird    NaN
# 236                  Black-Roses    NaN
# 259                Blizzard-Bush    NaN
# 319                   Blue-Trane    NaN
# 349          Blueberry-Triple-Og    NaN
# 353                   Blukashima    NaN
# 358             Bodega-Bubblegum    NaN
# 363                     Boombaye    NaN
# 377               Bright-Moments    NaN
# 378                 Broke-Diesel    NaN
# 379                Bronze-Whaler    NaN
# 384                  Bubba-Berry    NaN
# 385                   Bubba-Doja    NaN
# 387                   Bubba-Hash    NaN
# 409                Burnt-Cookies    NaN
# 413                           C3    NaN
# 417                  Cackleberry    NaN
# 428                     Calyx-Og    NaN
# 445  Caramel-Kona-Coffee-Cookies    NaN
# 466            Cbd-Rich-Blessing    NaN
# 483                Chem-Jong-Ill    NaN
# 504                  Cherry-Fire    NaN
# 523                   Chocoholic    NaN
# 530           Chocolate-Meringue    NaN
# 536              Chocolate-Tonic    NaN
# 574           Confidential-Wreck    NaN
# 613                      Cronuts    NaN
# 657                Diamond-Socks    NaN
# 668             Dj-Andy-Williams    NaN
# 672                   Do-Over-Og    NaN
# 678                       Domino    NaN
# 695                   Double-Tap    NaN
# 696                  Dougs-Varin    NaN
# 697                   Dr-Bubbles    NaN
# 701                   Dr-Quantum    NaN
# 768                      Erdpurt    NaN
# 770                        Ether    NaN
# 788              Fighting-Buddha    NaN
# 794                     First-48    NaN
# 818                 Frosty-Jesus    NaN
# 832                      G-Force    NaN
# 877               Godzilla-Blood    NaN
# 891                  Golden-Soda    NaN
# 896                     Goldwing    NaN
# 917                   Grape-Dawg    NaN
# 959                    Grimmdica    NaN
# 968                   Guido-Kush    NaN

# %%
flavors_dict = {
    '3-Bears-Og': 'Sweet, Earthy, Pungent',
    '831-Og': 'Spicy, Peppery, Citrusy',
    'Acid-Dough': 'Sweet, Earthy, Tropical',
    'Afrikaner': 'Sweet, Spicy, Earthy',
    'Allen-Iverson-Og': 'Sweet, Earthy, Pungent',
    'Alpha-Cow': 'Sweet, Berry, Earthy',
    'Als-Dream': 'Citrusy, Earthy, Pungent',
    'Amethyst': 'Berry, Sweet, Earthy',
    'Amnesia-Ganja-Haze': 'Sweet, Citrusy, Lemon',
    'Arabian-Gold': 'Earthy, Spicy',
    'Bad-Azz-Kush': 'Sweet, Earthy, Pine',
    'Batgirl': 'Sweet, Berry, Chemical',
    'Bcn-Diesel': 'Sour, Lemon, Earthy',
    'Bermuda-Sour': 'Diesel, Sweet, Citrusy',
    'Berts-Cookie-Dough': 'Sweet, Earthy, Vanilla',
    'Birds-Eye': 'Spicy, Sweet',
    'Black-Larry-Bird': 'Sweet, Lemon, Earthy',
    'Black-Roses': 'Earthy, Floral, Fruity',
    'Blizzard-Bush': 'Sweet, Diesel, Peppery',
    'Blue-Trane': 'Fruity, Sweet, Earthy',
    'Blueberry-Triple-Og': 'Earthy, Fruity',
    'Blukashima': 'Sweet, Berry, Spicy',
    'Bodega-Bubblegum': 'Sweet, Fruity, Earthy',
    'Boombaye': 'Earthy, Sweet, Floral',
    'Bright-Moments': 'Grape, Sweet, Floral',
    'Broke-Diesel': 'Sweet, Sour, Diesel',
    'Bronze-Whaler': 'Sweet, Citrus, Earthy',
    'Bubba-Berry': 'Sweet, Fruity, Spicy',
    'Bubba-Doja': 'Woody, Earthy',
    'Bubba-Hash': 'Spicy, Earthy, Sweet',
    'Burnt-Cookies': 'Lemon, Sour, Citrus, Fruity',
    'C3': 'Sweet, Spicy, Lemon',
    'Cackleberry': 'Berry, Sweet, Spicy, Fruity',
    'Calyx-Og': 'Earthy, Citrus, Sour',
    'Caramel-Kona-Coffee-Cookies': 'Sweet, Spicy, Coffee',
    'Cbd-Rich-Blessing': 'Earthy, Citrus, Sour',
    'Chem-Jong-Ill': 'Floral, Lemon, Chemical',
    'Cherry-Fire': 'Earthy, Sweet, Fruity',
    'Chocoholic': 'Berry, Sweet, Fruity',
    'Chocolate-Meringue': 'Lemon, Sweet, Earthy',
    'Chocolate-Tonic': 'Sweet, Herbal, Earthy',
    'Confidential-Wreck': 'Citrus, Earthy, Lemon',
    'Cronuts': 'Earthy, Woody, Sweet',
    'Diamond-Socks': 'Earthy, Fruity, Sweet',
    'Dj-Andy-Williams': 'Citrus, Vanilla, Herbal',
    'Do-Over-Og': 'Sweet, Pine, Spicy',
    'Domino': 'Spicy, Peppery',
    'Double-Tap': 'Berry, Grape, Sweet',
    'Dougs-Varin': 'Citrus, Spicy, Woody',
    'Dr-Bubbles': 'Floral, Fruity, Earthy, Sweet',
    'Dr-Quantum': 'Citrus, Earthy, SOur',
    'Erdpurt': 'Earthy, Berry, SPicy',
    'Ether': 'Chemical, Sweet, Diesel',
    'Fighting-Buddha': 'Spicy, Berry, Sweet',
    'First-48': 'Citrus, Fresh, Sour',
    'Frosty-Jesus': 'Sweet, Sour, Lemon',
    'G-Force': 'Diesel, Sweet',
    'Godzilla-Blood': 'Berry, Sour, Spicy',
    'Golden-Soda': 'Citrus, Grape, Sweet',
    'Goldwing': 'Herbal, Sweet',
    'Grape-Dawg': 'Fruity, Earthy, Sweet',
    'Grimmdica': 'Earthy, Butter, Cheese',
    'Guido-Kush': 'Fruity, Berry, Sweet'
}

# %%
for strain, flavor in flavors_dict.items():
    weed.loc[weed['strain'] == strain, 'flavor'] = flavor

# %%
weed.head()
# Out:
#        strain    type  rating                                     effects  \
# 0      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     0.0                           Relaxed, Euphoric
#
#                       flavor  \
# 0        Earthy,Sweet,Citrus
# 1    Spicy/Herbal,Sage,Woody
# 2  Apricot,Citrus,Grapefruit
# 3       Citrus,Earthy,Orange
# 4     Sweet, Earthy, Pungent
#
#                                          description
# 0  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  1024 is a sativa-dominant hybrid bred in Spain...
# 2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 3  Also known as Kosher Tangie, 24k Gold is a 60%...
# 4  3 Bears OG by Mephisto Genetics is an autoflow...

# %%
weed.isnull().sum()
# Out:
# strain          0
# type            0
# rating          0
# effects         0
# flavor          0
# description    11
# dtype: int64

# %% [markdown]
# ## Ratings Column

# %% [markdown]
# The ratings column didnt have any null values. However, I noticed that some of the values were 0 so I had to fill them in with the correct rating

# %%
zero_rating_strains = weed[weed['rating'] == 0.0]

# %%
zero_rating_strains[['strain', 'rating']]
# Out:
#                           strain  rating
# 4                     3-Bears-Og     0.0
# 52                     Afrikaner     0.0
# 164                   Bangi-Haze     0.0
# 185                 Bermuda-Sour     0.0
# 259                Blizzard-Bush     0.0
# 319                   Blue-Trane     0.0
# 358             Bodega-Bubblegum     0.0
# 363                     Boombaye     0.0
# 364                   Bootlegger     0.0
# 377               Bright-Moments     0.0
# 379                Bronze-Whaler     0.0
# 387                   Bubba-Hash     0.0
# 409                Burnt-Cookies     0.0
# 417                  Cackleberry     0.0
# 428                     Calyx-Og     0.0
# 445  Caramel-Kona-Coffee-Cookies     0.0
# 466            Cbd-Rich-Blessing     0.0
# 504                  Cherry-Fire     0.0
# 523                   Chocoholic     0.0
# 530           Chocolate-Meringue     0.0
# 536              Chocolate-Tonic     0.0
# 701                   Dr-Quantum     0.0
# 768                      Erdpurt     0.0
# 802                    Fn-Louzer     0.0
# 877               Godzilla-Blood     0.0
# 891                  Golden-Soda     0.0
# 917                   Grape-Dawg     0.0
# 979              Hannibal-Nectar     0.0

# %%
zero_rating = {
    '3-Bears-Og': 4.5,
    'Afrikaner': 4.4,
    'Bangi-Haze': 4.6,
    'Bermuda-Sour': 4.1,
    'Blizzard-Bush': 4.3,
    'Blue-Trane': 4.4,
    'Bodega-Bubblegum': 4.4,
    'Boombaye': 4.6,
    'Bootlegger': 4.5,
    'Bright-Moments': 4.7,
    'Bronze-Whaler': 4.1,
    'Bubba-Hash': 4.6,
    'Burnt-Cookies': 4.5,
    'Cackleberry': 4.7,
    'Calyx-Og': 4.4,
    'Caramel-Kona-Coffee-Cookies': 4.4,
    'Cbd-Rich-Blessing': 4.4,
    'Cherry-Fire': 4.7,
    'Chocoholic': 4.6,
    'Chocolate-Meringue': 4.6,
    'Chocolate-Tonic': 4.6,
    'Dr-Quantum': 4.4,
    'Erdpurt': 4.7,
    'Fn-Louzer': 4.4,
    'Godzilla-Blood': 4.3,
    'Golden-Soda': 4.5,
    'Grape-Dawg': 4.4,
    'Hannibal-Nectar': 4.4
}

# %% [markdown]
# ## Adding the updated ratings back to the original dataframe

# %%
for strain, rating in zero_rating.items():
    weed.loc[weed['strain'] == strain, 'rating'] = rating

# %%
weed.head()
# Out:
#        strain    type  rating                                     effects  \
# 0      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     4.5                           Relaxed, Euphoric
#
#                       flavor  \
# 0        Earthy,Sweet,Citrus
# 1    Spicy/Herbal,Sage,Woody
# 2  Apricot,Citrus,Grapefruit
# 3       Citrus,Earthy,Orange
# 4     Sweet, Earthy, Pungent
#
#                                          description
# 0  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  1024 is a sativa-dominant hybrid bred in Spain...
# 2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 3  Also known as Kosher Tangie, 24k Gold is a 60%...
# 4  3 Bears OG by Mephisto Genetics is an autoflow...

# %% [markdown]
# ## Decided I didn't need the description column so I dropped it

# %%
weed = weed.drop(columns=['description'])

# %%
weed.head()
# Out:
#        strain    type  rating                                     effects  \
# 0      100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1        1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 2    13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 3    24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
# 4  3-Bears-Og  indica     4.5                           Relaxed, Euphoric
#
#                       flavor
# 0        Earthy,Sweet,Citrus
# 1    Spicy/Herbal,Sage,Woody
# 2  Apricot,Citrus,Grapefruit
# 3       Citrus,Earthy,Orange
# 4     Sweet, Earthy, Pungent

# %%
weed.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Removing Duplicates

# %%
def has_duplicate_flavors(flavor_str):
    if pd.isna(flavor_str):
        return False
    flavors = flavor_str.split(',')
    return len(flavors) != len(set(flavors))

# %%
duplicate_flavors_rows = weed[weed['flavor'].apply(has_duplicate_flavors)]

# %%
duplicate_flavors_rows
# Out:
#             strain    type  rating                                  effects  \
# 275    Blue-Cheese  indica     4.3     Relaxed,Happy,Euphoric,Sleepy,Hungry
# 394  Bubble-Cheese  indica     3.8   Relaxed,Hungry,Sleepy,Tingly,Talkative
# 716  Durban-Cheese  hybrid     4.2  Hungry,Euphoric,Uplifted,Giggly,Relaxed
#
#                            flavor
# 275  Blue,Cheese,Cheese,Blueberry
# 394    Blue,Cheese,Cheese,Pungent
# 716     Blue,Cheese,Cheese,Earthy

# %%
def remove_duplicate_flavors(flavor_str):
    if pd.isna(flavor_str):
        return flavor_str
    flavors = flavor_str.split(',')
    unique_flavors = set(flavors)
    return ','.join(unique_flavors)

# %%
weed['flavor'] = weed['flavor'].apply(remove_duplicate_flavors)

# %%
weed[weed['flavor'].str.contains('Cheese', case=False, na=False)]
# Out:
#                       strain    type  rating  \
# 22                  Aberdeen  hybrid     4.3
# 65                   Alchemy  hybrid     4.8
# 78             Alien-Reunion  hybrid     4.9
# 108             Ancient-Kush  indica     4.6
# 155                 Balmoral  hybrid     4.2
# 164               Bangi-Haze  sativa     4.6
# 180                   Bedica  indica     4.3
# 191     Bertberry-Cheesecake  sativa     5.0
# 193              Bettie-Page  hybrid     4.2
# 199         Big-Budda-Cheese  hybrid     4.2
# 212                  Biochem  indica     4.4
# 219  Black-Cherry-Cheesecake  hybrid     4.5
# 273              Blue-Buddha  indica     4.9
# 275              Blue-Cheese  indica     4.3
# 285               Blue-Frost  hybrid     4.5
# 332     Blueberry-Cheesecake  hybrid     4.3
# 394            Bubble-Cheese  indica     3.8
# 456                 Cat-Piss  sativa     3.9
# 475                   Cheese  hybrid     4.1
# 476             Cheese-Candy  hybrid     4.3
# 478             Cheeseburger  hybrid     3.3
# 479              Cheesewreck  hybrid     4.3
# 519                  Chiesel  hybrid     4.4
# 520             China-Yunnan  indica     4.3
# 527         Chocolate-Fondue  sativa     4.6
# 573      Confidential-Cheese  indica     4.5
# 600          Critical-Cheese  hybrid     4.2
# 619                    Crypt  hybrid     4.4
# 624              Dairy-Queen  hybrid     4.4
# 645              Deep-Cheese  hybrid     4.3
# 716            Durban-Cheese  hybrid     4.2
# 777            Exodus-Cheese  hybrid     4.3
# 900          Gorilla-Biscuit  indica     4.7
# 910   Grandmas-Sugar-Cookies  indica     5.0
# 923                 Grape-Ox  indica     4.6
# 935             Green-Cheese  hybrid     4.1
# 956           Grilled-Cheese  hybrid     4.7
# 959                Grimmdica  indica     5.0
#
#                                           effects  \
# 22      Uplifted,Euphoric,Giggly,Energetic,Sleepy
# 65          Relaxed,Sleepy,Uplifted,Hungry,Tingly
# 78      Euphoric,Uplifted,Happy,Relaxed,Talkative
# 108     Sleepy,Relaxed,Aroused,Creative,Energetic
# 155      Relaxed,Happy,Uplifted,Focused,Talkative
# 164              Aroused,Uplifted,Euphoric,Hungry
# 180        Relaxed,Sleepy,Hungry,Focused,Euphoric
# 191  Uplifted,Creative,Euphoric,Focused,Energetic
# 193  Creative,Uplifted,Energetic,Euphoric,Relaxed
# 199        Happy,Relaxed,Euphoric,Uplifted,Giggly
# 212          Relaxed,Euphoric,Tingly,Sleepy,Happy
# 219     Creative,Relaxed,Euphoric,Hungry,Uplifted
# 273        Relaxed,Euphoric,Sleepy,Uplifted,Happy
# 275          Relaxed,Happy,Euphoric,Sleepy,Hungry
# 285      Uplifted,Happy,Relaxed,Euphoric,Creative
# 332        Happy,Relaxed,Uplifted,Euphoric,Tingly
# 394        Relaxed,Hungry,Sleepy,Tingly,Talkative
# 456     Happy,Uplifted,Euphoric,Relaxed,Talkative
# 475        Relaxed,Happy,Euphoric,Uplifted,Hungry
# 476        Relaxed,Uplifted,Happy,Sleepy,Creative
# 478      Tingly,Uplifted,Relaxed,Aroused,Creative
# 479      Happy,Relaxed,Uplifted,Creative,Euphoric
# 519       Happy,Euphoric,Relaxed,Uplifted,Focused
# 520        Uplifted,Happy,Relaxed,Euphoric,Sleepy
# 527       Uplifted,Relaxed,Happy,Euphoric,Focused
# 573          Sleepy,Uplifted,Relaxed,Tingly,Happy
# 600      Euphoric,Focused,Happy,Relaxed,Energetic
# 619       Relaxed,Euphoric,Focused,Happy,Uplifted
# 624      Happy,Relaxed,Euphoric,Uplifted,Creative
# 645    Relaxed,Uplifted,Creative,Hungry,Talkative
# 716       Hungry,Euphoric,Uplifted,Giggly,Relaxed
# 777       Uplifted,Relaxed,Euphoric,Happy,Focused
# 900        Relaxed,Euphoric,Creative,Sleepy,Happy
# 910      Relaxed,Happy,Energetic,Focused,Creative
# 923         Sleepy,Relaxed,Hungry,Tingly,Uplifted
# 935   Euphoric,Relaxed,Energetic,Focused,Creative
# 956  Uplifted,Creative,Energetic,Euphoric,Focused
# 959                              Euphoric,Relaxed
#
#                            flavor
# 22   Cheese,Blue,Menthol,Chemical
# 65      Cheese,Spicy/Herbal,Sweet
# 78           Pungent,Cheese,Skunk
# 108             Cheese,Mint,Skunk
# 155            Cheese,Pine,Earthy
# 164       Fruit,Berry,Cheese,Tree
# 180          Pungent,Cheese,Woody
# 191       Fruit,Berry,Cheese,Tree
# 193      Blue,Cheese,Sweet,Earthy
# 199         Cheese,Flowery,Earthy
# 212    Cheese,Spicy/Herbal,Earthy
# 219            Berry,Cheese,Sweet
# 273       Blueberry,Citrus,Cheese
# 275         Blueberry,Blue,Cheese
# 285      Blueberry,Menthol,Cheese
# 332        Blueberry,Cheese,Sweet
# 394           Blue,Cheese,Pungent
# 456      Blue,Cheese,Woody,Earthy
# 475         Pungent,Cheese,Earthy
# 476          Pungent,Cheese,Sweet
# 478             Cheese,Pepper,Tea
# 479          Pungent,Cheese,Woody
# 519         Cheese,Pungent,Diesel
# 520           Cheese,Sweet,Earthy
# 527           Cheese,Sweet,Earthy
# 573             Cheese,Woody,Pine
# 600         Pungent,Cheese,Earthy
# 619          Pungent,Cheese,Sweet
# 624           Cheese,Sweet,Earthy
# 645          Pungent,Cheese,Skunk
# 716            Blue,Cheese,Earthy
# 777       Blueberry,Citrus,Cheese
# 900            Cheese,Coffee,Pine
# 910          Pungent,Cheese,Sweet
# 923            Cheese,Grape,Sweet
# 935         Pungent,Cheese,Earthy
# 956         Pungent,Cheese,Pepper
# 959         Butter, Cheese,Earthy

# %%
def has_duplicate_effects(effects_str):
    if pd.isna(effects_str):
        return False
    effects = effects_str.split(',')
    return len(effects) != len(set(effects))

# %%
duplicate_effects_rows = weed[weed['effects'].apply(has_duplicate_effects)]

# %%
duplicate_effects_rows
# Out:
# Empty DataFrame
# Columns: [strain, type, rating, effects, flavor]
# Index: []

# %% [markdown]
# ## Updating the flavors that had word flaws

# %%
flavor_updates = {
    "Alice-In-Wonderland": "Pine,Minty,Sweet",
    "Ancient-Kush": "Skunk,Cheese,Minty",
    "Arjans-Ultra-Haze-1": "Minty,Earthy",
    "Banana-Cream-Og": "Minty,Pine",
    "Bubblegun": "Pepper,Minty,Blueberry",
    "Chemdawg-4-X-Alien-Og-Kush": "Nutty,Minty,Flowery",
    "Chicle": "Ammonia,Diesel,Minty",
    "Double-Mint": "Minty, Lemon",
    "Dutch-Dragon": "Citrus,Sweet,Minty",
    "Goldberry": "Minty,Earthy,Woody",
    "Guava-Gelato": "Minty,Grapefruit,Tropical",
    "Harlequin-Gdp": "Minty,Earthy",
    "Hashberry": "Berry,Sweet,Minty",
    "Banana-Candy": "Tree,Fruity,Earthy,Sweet",
    "Banana-Kush": "Sweet,Tropical,Tree,Fruity",
    "Bangi-Haze": "Berry,Tree,Fruity,Cheese",
    "Bc-Sweet-Tooth": "Sweet,Honey,Tree,Fruity",
    "Bertberry-Cheesecake": "Cheese,Berry,Tree,Fruity",
    "Blue-Diamond": "Sweet,Tree,Fruity,Pineapple",
    "Enemy-Of-The-State": "Spicy,Herbal,Tree,Fruity,Earthy",
    "Fred-Flipn-Stoned": "Spicy,Herbal,Sage,Tree,Fruit",
    "Aberdeen": "Menthol,Blueberry,Cheese,Chemical",
    "Bettie-Page": "Earthy,Sweet,Blue,Cheese",
    "Blue-Cheese": "Cheese,Blueberry",
    "Bubble-Cheese": "Blueberry,Cheese,Pungent",
    "Cat-Piss": "Earthy,Woody,Blueberry,Cheese",
    "Durban-Cheese": "Blueberry,Cheese,Earthy",
    "831-Og": "Spicy, Pepper, Citrus",
    "Als-Dream": "Citrus, Earthy, Pungent",
    "Amnesia-Ganja-Haze": "Sweet, Citrus, Lemon",
    "Bermuda-Sour": "Diesel, Sweet, Citrus",
    "Black-Roses": "Earthy, Flowery, Fruity",
    "Boombaye": "Earthy, Sweet, Flowery",
    "Bright-Moments": "Grape, Sweet, Flowery",
    "Chem-Jong-Ill": "Flowery, Lemon, Chemical",
    "Dr-Bubbles": "Flowery, Fruity, Earthy, Sweet",
    "Blizzard-Bush": "Sweet, Diesel, Pepper",
    "Domino": "Spicy, Pepper",
    "Dr-Quantum": "Citrus, Earthy, Sour",
    "1024": "Spicy,Herbal, Sage, Woody",
    "Ace-Killer-Og": "Earthy, Diesel, Spicy,Herbal",
    "Afghani-Cbd": "Flowery, Chemical, Spicy,Herbal",
    "Afpak": "Pine, Spicy,Herbal, Earthy",
    "African": "Spicy,Herbal, Pungent, Pepper",
    "Air-Jordan-Og": "Diesel, Pine, Spicy,Herbal",
    "Alaskan-Ice": "Sweet, Earthy, Spicy,Herbal",
    "Alchemy": "Cheese, Sweet, Spicy,Herbal",
    "Alien-Stardawg": "Diesel, Spicy,Herbal, Sage",
    "Alien-Technology": "Earthy, Spicy,Herbal, Woody",
    "Allkush": "Spicy,Herbal, Honey, Earthy",
    "Alpha-Express": "Diesel, Earthy, Spicy,Herbal",
    "Alpha-Og": "Spicy,Herbal, Sweet, Berry",
    "Americano": "Earthy, Spicy,Herbal, Tobacco",
    "Apollo-13": "Earthy, Spicy,Herbal, Sweet",
    "Argyle": "Spicy,Herbal, Pungent, Earthy",
    "Armagnac": "Spicy,Herbal, Sweet, Flowery",
    "Ash": "Pungent, Skunk, Spicy,Herbal",
    "Aspen-Og": "Blueberry, Spicy,Herbal, Earthy",
    "Atomic-Goat": "Spicy,Herbal, Nutty, Sage",
    "Aurora-Indica": "Earthy, Spicy,Herbal, Tropical",
    "Ayahuasca-Purple": "Spicy,Herbal, Pungent, Earthy",
    "B4": "Spicy,Herbal, Berry, Skunk",
    "Banana-Peel": "Spicy,Herbal, Tropical, Earthy",
    "Bianca": "Earthy, Woody, Spicy,Herbal",
    "Big-Band": "Sweet, Spicy,Herbal, Sage",
    "Big-Smooth": "Blueberry, Spicy,Herbal, Nutty",
    "Biker-Leblanc": "Spicy,Herbal, Sage, Earthy",
    "Biochem": "Spicy,Herbal, Earthy, Cheese",
    "Black-Dhalia": "Sweet, Earthy, Spicy,Herbal",
    "Blackberry-Diesel": "Diesel, Spicy,Herbal, Pungent",
    "Blackberry-Dream": "Spicy,Herbal, Sweet, Grapefruit",
    "Blackberry-Haze": "Berry, Sweet, Spicy,Herbal",
    "Blackberry-Rhino": "Berry, Sweet, Spicy,Herbal",
    "Bloodhound": "Earthy, Sage, Spicy,Herbal",
    "Blowfish": "Spicy,Herbal, Pepper, Sage",
    "Blucifer": "Blueberry, Spicy,Herbal, Berry",
    "Blue-Dynamite": "Berry, Spicy,Herbal, Pine",
    "Blue-Heron": "Woody, Spicy,Herbal, Pine",
    "Brazil-Amazonia": "Spicy,Herbal, Berry, Earthy",
    "Caramella": "Menthol, Spicy,Herbal, Sweet",
    "Cbd-Kush": "Earthy, Woody, Spicy,Herbal",
    "Cello-Sweet-Og": "Sweet, Spicy,Herbal, Pineapple",
    "Cherry-Sauce": "Spicy,Herbal, Sweet, Flowery",
    "Chloe": "Earthy, Spicy,Herbal, Sweet",
    "Chocolate-Thai": "Spicy,Herbal, Coffee, Woody",
    "Chocolate-Thunder": "Honey, Nutty, Spicy,Herbal",
    "Chronic": "Woody, Spicy,Herbal, Sweet",
    "Clockwork-Orange": "Spicy,Herbal, Sweet, Citrus",
    "Colombian-Gold": "Earthy, Pungent, Spicy,Herbal",
    "Conspiracy-Kush": "Spicy,Herbal, Berry, Earthy",
    "Corleone-Kush": "Earthy, Spicy,Herbal, Flowery",
    "Critical-Plus": "Woody, Spicy,Herbal, Pungent",
    "Crouching-Tiger-Hidden-Alien": "Pine, Spicy,Herbal, Earthy",
    "Dakini-Kush": "Earthy, Coffee, Spicy,Herbal",
    "Damnesia": "Spicy,Herbal, Pepper, Earthy",
    "Dance-World": "Earthy, Citrus, Spicy,Herbal",
    "Dark-Side-Of-The-Moon": "Berry, Earthy, Spicy,Herbal",
    "Dawgfather-Og": "Spicy,Herbal, Pepper, Pungent",
    "Devil-Fruit": "Spicy,Herbal, Pepper, Sweet",
    "Devils-Tit": "Spicy,Herbal, Pepper, Earthy",
    "Diablo": "Sweet, Earthy, Spicy,Herbal",
    "Diamond-Og": "Earthy, Spicy,Herbal, Pine",
    "Diamond-Valley-Kush": "Earthy, Spicy,Herbal, Pungent",
    "Digweed": "Earthy, Skunk, Spicy,Herbal",
    "Dirty-Old-Bastard": "Spicy,Herbal, Flowery",
    "Dizzy-Og": "Sweet, Pungent, Spicy,Herbal",
    "Dorit": "Ammonia, Spicy,Herbal, Minty",
    "Dragons-Breath": "Spicy,Herbal, Earthy, Skunk",
    "Dream-Beaver": "Pineapple, Woody, Spicy,Herbal",
    "Dream-Lotus": "Spicy,Herbal, Woody, Tea",
    "Dutch-Crunch": "Spicy,Herbal, Pepper, Citrus",
    "Early-Miss": "Pepper, Ammonia, Spicy,Herbal",
    "Earth-Og": "Earthy, Spicy,Herbal, Pine",
    "East-Coast-Alien": "Diesel, Earthy, Spicy,Herbal",
    "Easy-Bud": "Lemon, Skunk, Spicy,Herbal",
    "Easy-Peezy": "Lemon, Spicy,Herbal, Earthy",
    "Ebola-7": "Sweet, Spicy,Herbal, Pine",
    "El-Nino": "Earthy, Woody, Spicy,Herbal",
    "Enemy-Of-The-State": "Spicy,Herbal, Tree, Fruit, Earthy",
    "Faygo-Red-Pop": "Strawberry, Spicy,Herbal, Sage",
    "Fire-Alien-Kush": "Earthy, Woody, Spicy,Herbal",
    "Fire-Alien-Strawberry": "Spicy,Herbal, Strawberry, Earthy",
    "Flaming-Cookies": "Spicy,Herbal, Sweet, Diesel",
    "Four-Cups": "Earthy, Diesel, Spicy,Herbal",
    "Fred-Flipn-Stoned": "Spicy,Herbal, Sage, Tree, Fruit",
    "Full-Moon": "Spicy,Herbal, Citrus, Earthy",
    "Galactica-Og": "Spicy,Herbal, Earthy, Pungent",
    "Gigabud": "Sweet, Spicy,Herbal, Tropical",
    "Gobbstopper": "Spicy,Herbal, Sweet, Berry",
    "Godfather-Og": "Earthy, Pine, Spicy,Herbal",
    "Godfather-Purple-Kush": "Berry, Spicy,Herbal, Pungent",
    "Godzilla-Glue": "Tropical, Spicy,Herbal, Sweet",
    "Gog-Magog": "Earthy, Pungent, Spicy,Herbal",
    "Golden-Gage": "Pepper, Spicy,Herbal, Citrus",
    "Good-Medicine": "Earthy, Spicy,Herbal, Citrus",
    "Green-Crack-Extreme": "Sweet, Earthy, Spicy,Herbal",
    "Green-Door-Kush": "Spicy,Herbal, Citrus, Woody",
    "Green-Love-Potion": "Spicy,Herbal, Lavender, Sweet",
    "Grimace-Og": "Pungent, Diesel, Spicy,Herbal",
    "Harle-Tsu": "Earthy, Woody, Spicy,Herbal",
    "Harley-Storm": "Spicy,Herbal, Sweet, Tropical",
    "Hash-Plant": "Earthy, Spicy,Herbal, Diesel"
}

# %% [markdown]
# ## Adding the updates back to the original dataframe

# %%
for strain, flavor in flavor_updates.items():
    weed.loc[weed['strain'] == strain, 'flavor'] = flavor

# %%
weed.head(20)
# Out:
#                     strain    type  rating  \
# 0                   100-Og  hybrid     4.0
# 1                     1024  sativa     4.4
# 2                 13-Dawgs  hybrid     4.2
# 3                 24K-Gold  hybrid     4.6
# 4               3-Bears-Og  indica     4.5
# 5                  3-Kings  hybrid     4.4
# 6                   303-Og  indica     4.2
# 7                   3D-Cbd  sativa     4.6
# 8   3Rd-Coast-Panama-Chunk  hybrid     4.7
# 9                 3X-Crazy  indica     4.4
# 10                501St-Og  hybrid     4.5
# 11             5Th-Element  indica     4.4
# 12            707-Headband  hybrid     4.3
# 13             8-Ball-Kush  indica     4.3
# 14                  818-Og  indica     4.7
# 15                  831-Og  indica     5.0
# 16          9-Pound-Hammer  indica     4.5
# 17                91-Krypt  indica     4.7
# 18          98-White-Widow  hybrid     4.7
# 19                    A-10  indica     3.8
#
#                                        effects                     flavor
# 0   Creative,Energetic,Tingly,Euphoric,Relaxed        Citrus,Sweet,Earthy
# 1    Uplifted,Happy,Relaxed,Energetic,Creative  Spicy,Herbal, Sage, Woody
# 2      Tingly,Creative,Hungry,Relaxed,Uplifted  Grapefruit,Citrus,Apricot
# 3    Happy,Relaxed,Euphoric,Uplifted,Talkative       Citrus,Orange,Earthy
# 4                            Relaxed, Euphoric      Earthy,Sweet, Pungent
# 5       Relaxed,Euphoric,Happy,Uplifted,Hungry       Pungent,Sweet,Earthy
# 6       Relaxed,Happy,Euphoric,Uplifted,Giggly      Pungent,Citrus,Earthy
# 7     Uplifted,Focused,Happy,Talkative,Relaxed       Flowery,Woody,Earthy
# 8           Energetic,Happy,Talkative,Uplifted                Diesel,Pine
# 9       Relaxed,Tingly,Happy,Euphoric,Uplifted         Sweet,Grape,Earthy
# 10     Relaxed,Euphoric,Sleepy,Happy,Talkative          Skunk,Pine,Earthy
# 11   Relaxed,Focused,Euphoric,Uplifted,Aroused          Woody,Pine,Earthy
# 12  Euphoric,Happy,Uplifted,Talkative,Creative       Pungent,Woody,Earthy
# 13    Relaxed,Uplifted,Happy,Creative,Euphoric         Citrus,Pine,Earthy
# 14        Relaxed,Happy,Euphoric,Giggly,Sleepy      Diesel,Flowery,Earthy
# 15                   Relaxed, Hungry, Creative      Spicy, Pepper, Citrus
# 16        Relaxed,Sleepy,Euphoric,Happy,Hungry         Berry,Sweet,Earthy
# 17      Relaxed,Euphoric,Happy,Hungry,Uplifted       Pungent,Berry,Earthy
# 18    Relaxed,Aroused,Creative,Happy,Energetic      Violet,Flowery,Diesel
# 19       Relaxed,Focused,Happy,Sleepy,Uplifted       Pungent,Citrus,Sweet

# %% [markdown]
# ## Final cleaned dataframe

# %%
weed.to_csv('clean_weed.csv', index=False)
